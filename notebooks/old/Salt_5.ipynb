# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *
from fastai.models.resnet import vgg_resnet50

import json

# %%
#torch.cuda.set_device(2)

# %%
torch.backends.cudnn.benchmark=True

# %% [markdown]
# ## Data

# %%
PATH = Path('/home/giles/Downloads/fastai_data/salt/')
MASKS_FN = 'train_masks.csv'
META_FN = 'metadata.csv'
masks_csv = pd.read_csv(PATH/MASKS_FN)
meta_csv = pd.read_csv(PATH/META_FN)

# %%
def show_img(im, figsize=None, ax=None, alpha=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im, alpha=alpha)
    ax.set_axis_off()
    return ax

# %%
(PATH/'train_masks-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train_masks-128'/fn.name)

files = list((PATH/'train_masks').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
(PATH/'train-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train-128'/fn.name)

files = list((PATH/'train').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
TRAIN_DN = 'train-128'
MASKS_DN = 'train_masks-128'
sz = 32
bs = 64
nw = 16

# %% [markdown]
# TRAIN_DN = 'train'
# MASKS_DN = 'train_masks_png'
# sz = 128
# bs = 64
# nw = 16

# %%
class MatchedFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.y[i]))
    def get_c(self): return 0

# %%
x_names = np.array(glob(f'{PATH}/{TRAIN_DN}/*'))
y_names = np.array(glob(f'{PATH}/{MASKS_DN}/*'))

# %%
val_idxs = list(range(800))
((val_x,trn_x),(val_y,trn_y)) = split_by_idx(val_idxs, x_names, y_names)

# %%
aug_tfms = [RandomFlip(tfm_y=TfmType.CLASS)]

# %%
tfms = tfms_from_model(resnext50, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
x,y = next(iter(md.trn_dl))

# %%
x.shape,y.shape
# Out:
# (torch.Size([64, 3, 32, 32]), torch.Size([64, 32, 32]))

# %%
denorm = md.val_ds.denorm

# %%
def show_aug_img(ims, idx, figsize=(5,5), normed=True, ax=None, nchannels=3):
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    if normed: ims = denorm(ims)
    else:      ims = np.rollaxis(to_np(ims),1,nchannels+1)
    ax.imshow(np.clip(ims,0,1)[idx])
    ax.axis('off')

# %%
batches = [next(iter(md.aug_dl)) for i in range(9)]

# %%
fig, axes = plt.subplots(3, 6, figsize=(18, 9))
for i,(x,y) in enumerate(batches):
    show_aug_img(x,1, ax=axes.flat[i*2])
    show_aug_img(y,1, ax=axes.flat[i*2+1], nchannels=1, normed=False)

# %% [markdown]
# ## Simple upsample

# %%
f = resnext50
cut,lr_cut = model_meta[f]

# %%
def get_base():
    layers = cut_model(f(True), cut)
    return nn.Sequential(*layers)

# %%
def dice(pred, targs):
    pred = (pred>0.5).float()
    return 2. * (pred*targs).sum() / (pred+targs).sum()

# %% [markdown]
# ## U-net (ish)

# %%
class SaveFeatures():
    features=None
    def __init__(self, m): self.hook = m.register_forward_hook(self.hook_fn)
    def hook_fn(self, module, input, output): self.features = output
    def remove(self): self.hook.remove()

# %%
class UnetBlock(nn.Module):
    def __init__(self, up_in, x_in, n_out):
        super().__init__()
        up_out = x_out = n_out//2
        self.x_conv  = nn.Conv2d(x_in,  x_out,  1)
        self.tr_conv = nn.ConvTranspose2d(up_in, up_out, 2, stride=2)
        self.bn = nn.BatchNorm2d(n_out)
        
    def forward(self, up_p, x_p):
        up_p = self.tr_conv(up_p)
        x_p = self.x_conv(x_p)
        cat_p = torch.cat([up_p,x_p], dim=1)
        return self.bn(F.relu(cat_p))

# %%
class Unet34(nn.Module):
    def __init__(self, rn):
        super().__init__()
        self.rn = rn
        self.sfs = [SaveFeatures(rn[i]) for i in [2,4,5,6]]
        self.up1 = UnetBlock(2048,1024,256)
        self.up2 = UnetBlock(256,512,256)
        self.up3 = UnetBlock(256,256,256)
        self.up4 = UnetBlock(256,64,256)
        self.up5 = nn.ConvTranspose2d(256, 1, 2, stride=2)
        
    def forward(self,x):
        x = F.relu(self.rn(x))
        x = self.up1(x, self.sfs[3].features)
        x = self.up2(x, self.sfs[2].features)
        x = self.up3(x, self.sfs[1].features)
        x = self.up4(x, self.sfs[0].features)
        x = self.up5(x)
        return x[:,0]
    
    def close(self):
        for sf in self.sfs: sf.remove()

# %%
class UnetModel():
    def __init__(self,model,name='unet'):
        self.model,self.name = model,name

    def get_layer_groups(self, precompute):
        lgs = list(split_by_idxs(children(self.model.rn), [lr_cut]))
        return lgs + [children(self.model)[1:]]

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 32, 32]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 512, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 512, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-138',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-139',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-141',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-142',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-144',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-145',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-146',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-147',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-148',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-150',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-151',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-153',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-154',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-155',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-156',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-157',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 128, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 1048704)])),
#              ('Conv2d-158',
#               OrderedDict([('input_shape', [-1, 1024, 2, 2]),
#                            ('output_shape', [-1, 128, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('BatchNorm2d-159',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-160',
#               OrderedDict([('input_shape', [-1, 2048, 1, 1]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-161',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-162',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 65664)])),
#              ('BatchNorm2d-163',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-164',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-165',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-166',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 32896)])),
#              ('BatchNorm2d-167',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-168',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-169',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 128, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-170',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 128, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 8320)])),
#              ('BatchNorm2d-171',
#               OrderedDict([('input_shape', [-1, 256, 16, 16]),
#                            ('output_shape', [-1, 256, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-172',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 16, 16]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-173',
#               OrderedDict([('input_shape', [-1, 256, 16, 16]),
#                            ('output_shape', [-1, 1, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1025)]))])

# %%
[o.features.size() for o in m.sfs]
# Out:
# [torch.Size([3, 64, 16, 16]),
#  torch.Size([3, 256, 8, 8]),
#  torch.Size([3, 512, 4, 4]),
#  torch.Size([3, 1024, 2, 2])]

# %%
learn.freeze_to(1)

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  86%|████████▌ | 43/50 [00:03<00:00, 13.03it/s, loss=1.27]

# %%
lr=5e-2
wd=1e-7

lrs = np.array([lr/100,lr/10,lr])

# %%
learn.fit(lr,1,wds=wd,cycle_len=8,use_clr=(5,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.301537   0.394205   0.845468   0.580743
#     1      0.265265   0.240919   0.904601   0.797483
#     2      0.246994   0.297469   0.905454   0.818141
#     3      0.222933   0.213095   0.90203    0.771763
#     4      0.202111   0.219421   0.91642    0.827787
#     5      0.18251    0.206899   0.920098   0.825356
#     6      0.17161    0.201748   0.921448   0.831911
#     7      0.156599   0.202739   0.92043    0.827159
# [array([0.20274]), 0.9204296875, 0.827159254589152]

# %%
learn.save('32urn-tmp')

# %%
learn.load('32urn-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
learn.fit(lrs/4, 1, wds=wd, cycle_len=20,use_clr=(20,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=20), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.13424    0.234751   0.907134   0.783958
#     1      0.134968   0.20058    0.92693    0.848189
#     2      0.138677   0.20553    0.92353    0.834294
#     3      0.12412    0.222445   0.930188   0.857619
#     4      0.145902   0.205154   0.921901   0.840887
#     5      0.126439   0.213108   0.927072   0.852044
#     6      0.108215   0.210459   0.932134   0.862909
#     7      0.094444   0.21582    0.934772   0.862476
#     8      0.087564   0.216884   0.935901   0.868293
#     9      0.083356   0.22234    0.933706   0.862755
#     10     0.079373   0.258096   0.934969   0.863515
#     11     0.072585   0.242495   0.936898   0.868165
#     12     0.068426   0.250044   0.934669   0.862541
#     13     0.065872   0.24924    0.932134   0.864702
#     14     0.063315   0.247247   0.936132   0.867994
#     15     0.061259   0.249231   0.936425   0.870232
#     16     0.058345   0.27581    0.936239   0.869087
#     17     0.056897   0.26834    0.937677   0.871164
#     18     0.056043   0.259384   0.938336   0.871764
#     19     0.054251   0.266745   0.93752    0.87078
# [array([0.26675]), 0.93751953125, 0.8707796154376136]

# %%
learn.sched.plot_lr()

# %%
learn.save('32urn-0')

# %%
learn.load('32urn-0')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[0]>0.5);

# %%
show_img(y[0]);

# %%
show_img(x[0][0]);

# %%
m.close()

# %% [markdown]
# ## 64x64

# %%
sz=64
bs=64

# %%
tfms = tfms_from_model(resnext50, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.freeze_to(1)

# %%
learn.load('32urn-0')

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  82%|████████▏ | 41/50 [00:04<00:00,  9.60it/s, loss=0.452]

# %%
learn.fit(lr,1,wds=wd, cycle_len=5,use_clr=(5,5))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.192121   0.209836   0.933614   0.857659
#     1      0.178665   0.231367   0.904843   0.780554
#     2      0.166477   0.168824   0.936382   0.863211
#     3      0.139018   0.164714   0.938545   0.869657
#     4      0.121978   0.152991   0.942002   0.878502
# [array([0.15299]), 0.942001953125, 0.8785015674833297]

# %%
learn.sched.plot_lr()

# %%
learn.save('64urn-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
learn.load('64urn-tmp')

# %%
learn.fit(lrs/4,1,wds=wd, cycle_len=8,use_clr=(20,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.096851   0.193781   0.936201   0.86393
#     1      0.111627   0.177951   0.939611   0.878026
#     2      0.099089   0.161618   0.939935   0.871858
#     3      0.089263   0.15734    0.946977   0.892073
#     4      0.077465   0.170517   0.94851    0.893647
#     5      0.068202   0.159935   0.949591   0.898157
#     6      0.062585   0.175741   0.948054   0.892978
#     7      0.058818   0.177852   0.948025   0.892794
# [array([0.17785]), 0.9480252075195312, 0.8927937774726175]

# %%
learn.sched.plot_lr()

# %%
learn.save('64urn')

# %%
learn.load('64urn')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[0]>0.5);

# %%
show_img(y[0]);

# %%
show_img(x[0][0]);

# %%
m.close()

# %% [markdown]
# ## 128x128

# %%
sz=128
bs=64

# %%
tfms = tfms_from_model(resnext50, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('64urn')
learn.freeze_to(1)
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  86%|████████▌ | 43/50 [00:08<00:01,  5.27it/s, loss=0.676]

# %%
learn.fit(lr,1, wds=wd, cycle_len=3,use_clr=(3,2))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.179814   0.171986   0.937415   0.872139
#     1      0.171026   0.178009   0.934187   0.858185
#     2      0.154557   0.163032   0.936569   0.863032
# [array([0.16303]), 0.9365688323974609, 0.8630319059768253]

# %%
learn.save('128urn-tmp')

# %%
learn.load('128urn-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
lrs = np.array([lr/200,lr/30,lr])

# %%
wd
# Out:
# 1e-07

# %%
learn.fit(lrs/10,1, wds=wd,cycle_len=4,use_clr=(20,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=4), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.121558   0.147663   0.945353   0.885863
#     1      0.113929   0.150324   0.945697   0.886503
#     2      0.106901   0.149882   0.946387   0.888193
#     3      0.1014     0.149223   0.946636   0.889346
# [array([0.14922]), 0.9466355133056641, 0.8893460672386884]

# %%
learn.sched.plot_lr()

# %%
learn.sched.plot_loss()

# %%
learn.save('128urn')

# %%
learn.load('128urn')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[0]>0.5);

# %%
show_img(y[0]);

# %%
show_img(x[0][0]);

# %%
y.shape
# Out:
# torch.Size([64, 128, 128])

# %%
batches = [next(iter(md.aug_dl)) for i in range(9)]

# %%
fig, axes = plt.subplots(3, 6, figsize=(18, 9))
for i,(x,y) in enumerate(batches):
    show_aug_img(x,1, ax=axes.flat[i*2])
    show_aug_img(y,1, ax=axes.flat[i*2+1], nchannels=1, normed=False)

# %% [markdown]
# # Test on original validation

# %%
x_names_orig = np.array(glob(f'{PATH}/train/*'))
y_names_orig = np.array(glob(f'{PATH}/train_masks/*'))

# %%
val_idxs_orig = list(range(800))
((val_x_orig,trn_x_orig),(val_y_orig,trn_y_orig)) = split_by_idx(val_idxs_orig, x_names_orig, y_names_orig)

# %%
sz=128
bs=64

# %%
tfms = tfms_from_model(resnext50, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('128urn')

# %%
probs = learn.predict()

# %%
probs.shape
# Out:
# (800, 128, 128)

# %%
_, y = learn.TTA(n_aug=1)

# %%
y.shape
# Out:
# (800, 128, 128)

# %%
idx=0

# %%
show_img(probs[idx]>0.5);

# %%
show_img(probs[idx]);

# %%
show_img(y[idx]);

# %%
show_img(x[idx][0]);

# %% [markdown]
# # Optimise threshold

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thres = np.linspace(-5, 5, 50)
thres_ioc = [iou_metric_batch(y, np.int32(probs > t)) for t in tqdm_notebook(thres)]
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
plt.plot(thres, thres_ioc);

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.5102040816326534, 0.730125)

# %%
thres = np.linspace(0, 1, 100)
thres_ioc = [iou_metric_batch(y, np.int32(probs > t)) for t in tqdm_notebook(thres)]
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
plt.plot(thres, thres_ioc);

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.5050505050505051, 0.7303750000000001)

# %%
show_img(probs[0]>best_thres);

# %% [markdown]
# # Run on test

# %%
(PATH/'test-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'test-128'/fn.name)

files = list((PATH/'test').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
testData = np.array(glob(f'{PATH}/test-128/*'))

# %%
class TestFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.fnames[i]))
    def get_c(self): return 0

# %%
tfms_from_model(resnext50, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(TestFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, test=testData, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('128urn')

# %%
x,y = next(iter(md.test_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[6]>best_thres);

# %%
show_img(py[6]);

# %%
show_img(y[6]);

# %%
probs = learn.predict(is_test=True)

# %%
show_img(probs[12]>best_thres);

# %%
show_img(probs[12]);

# %%
show_img(y[12]);

# %%
show_img(x[12][0]);

# %%
with open(f'{PATH}/probs.pkl', 'wb') as fout: #Save results
    pickle.dump(probs, fout)

# %%
probs.shape
# Out:
# (18000, 128, 128)

# %%
def resize_img(fn):
    return np.array(Image.fromarray(fn).resize((101,101)))

resizePreds = np.array([resize_img(x) for x in probs])

# %%
resizePreds.shape
# Out:
# (18000, 101, 101)

# %%
show_img(resizePreds[12]);

# %%
testData
# Out:
# array(['/home/giles/Downloads/fastai_data/salt/test-128/ac26efe98e.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/0a5eac8775.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/bdb1c1fcbf.png', ...,
#        '/home/giles/Downloads/fastai_data/salt/test-128/3bceaa0303.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/96867a3897.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/52f6267e3f.png'], dtype='<U62')

# %%
f'{PATH}/test'
# Out:
# '/home/giles/Downloads/fastai_data/salt/test'

# %%
test_ids = next(os.walk(f'{PATH}/test'))[2]

# %%
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

# %%
pred_dict = {id_[:-4]:RLenc(np.round(resizePreds[i] > best_thres)) for i,id_ in tqdm_notebook(enumerate(test_ids))}
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')

# %%
sub
# Out:
#                                                      rle_mask
# id
# ac26efe98e  1 32 53 5 102 29 132 2 154 5 203 32 254 6 304 ...
# 0a5eac8775
# bdb1c1fcbf  5955 1 6055 3 6459 2 6462 3 6560 5 6661 2 6664...
# 5358961921
# b7b72a69d1
# c1169d47ce
# 89eb8ef89f  7473 2 7573 3 7674 3 7768 10 7866 13 7967 13 8...
# 696d91b37e
# 73053e4d03  612 5 620 3 705 3 711 6 721 3 805 4 812 6 822 ...
# 68dd1c44ae
# 6ba0ff2b77
