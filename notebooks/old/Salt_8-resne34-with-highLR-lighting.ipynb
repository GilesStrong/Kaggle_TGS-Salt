# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *
from fastai.models.resnet import vgg_resnet50

import json

# %%
#torch.cuda.set_device(2)

# %%
torch.backends.cudnn.benchmark=True

# %% [markdown]
# ## Data

# %%
PATH = Path('/home/giles/Downloads/fastai_data/salt/')
MASKS_FN = 'train_masks.csv'
META_FN = 'metadata.csv'
masks_csv = pd.read_csv(PATH/MASKS_FN)
meta_csv = pd.read_csv(PATH/META_FN)

# %%
def show_img(im, figsize=None, ax=None, alpha=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im, alpha=alpha)
    ax.set_axis_off()
    return ax

# %%
(PATH/'train_masks-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train_masks-128'/fn.name)

files = list((PATH/'train_masks').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
(PATH/'train-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train-128'/fn.name)

files = list((PATH/'train').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
TRAIN_DN = 'train-128'
MASKS_DN = 'train_masks-128'
sz = 32
bs = 64
nw = 16

# %% [markdown]
# TRAIN_DN = 'train'
# MASKS_DN = 'train_masks_png'
# sz = 128
# bs = 64
# nw = 16

# %%
class MatchedFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.y[i]))
    def get_c(self): return 0

# %%
x_names = np.array(glob(f'{PATH}/{TRAIN_DN}/*'))
y_names = np.array(glob(f'{PATH}/{MASKS_DN}/*'))

# %%
val_idxs = list(range(800))
((val_x,trn_x),(val_y,trn_y)) = split_by_idx(val_idxs, x_names, y_names)

# %%
aug_tfms = [RandomFlip(tfm_y=TfmType.CLASS), RandomLighting(0.05, 0.05, tfm_y=TfmType.CLASS)]

# %%
tfms = tfms_from_model(resnet34, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
x,y = next(iter(md.trn_dl))

# %%
x.shape,y.shape
# Out:
# (torch.Size([64, 3, 32, 32]), torch.Size([64, 32, 32]))

# %%
denorm = md.val_ds.denorm

# %%
def show_aug_img(ims, idx, figsize=(5,5), normed=True, ax=None, nchannels=3):
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    if normed: ims = denorm(ims)
    else:      ims = np.rollaxis(to_np(ims),1,nchannels+1)
    ax.imshow(np.clip(ims,0,1)[idx])
    ax.axis('off')

# %%
batches = [next(iter(md.aug_dl)) for i in range(9)]

# %%
fig, axes = plt.subplots(3, 6, figsize=(18, 9))
for i,(x,y) in enumerate(batches):
    show_aug_img(x,1, ax=axes.flat[i*2])
    show_aug_img(y,1, ax=axes.flat[i*2+1], nchannels=1, normed=False)

# %% [markdown]
# ## Simple upsample

# %%
f = resnet34
cut,lr_cut = model_meta[f]

# %%
def get_base():
    layers = cut_model(f(True), cut)
    return nn.Sequential(*layers)

# %%
def dice(pred, targs):
    pred = (pred>0.5).float()
    return 2. * (pred*targs).sum() / (pred+targs).sum()

# %% [markdown]
# ## U-net (ish)

# %%
class SaveFeatures():
    features=None
    def __init__(self, m): self.hook = m.register_forward_hook(self.hook_fn)
    def hook_fn(self, module, input, output): self.features = output
    def remove(self): self.hook.remove()

# %%
class UnetBlock(nn.Module):
    def __init__(self, up_in, x_in, n_out):
        super().__init__()
        up_out = x_out = n_out//2
        self.x_conv  = nn.Conv2d(x_in,  x_out,  1)
        self.tr_conv = nn.ConvTranspose2d(up_in, up_out, 2, stride=2)
        self.bn = nn.BatchNorm2d(n_out)
        
    def forward(self, up_p, x_p):
        up_p = self.tr_conv(up_p)
        x_p = self.x_conv(x_p)
        cat_p = torch.cat([up_p,x_p], dim=1)
        return self.bn(F.relu(cat_p))

# %%
class Unet34(nn.Module):
    def __init__(self, rn):
        super().__init__()
        self.rn = rn
        self.sfs = [SaveFeatures(rn[i]) for i in [2,4,5,6]]
        self.up1 = UnetBlock(512,256,256)
        self.up2 = UnetBlock(256,128,256)
        self.up3 = UnetBlock(256,64,256)
        self.up4 = UnetBlock(256,64,256)
        self.up5 = nn.ConvTranspose2d(256, 1, 2, stride=2)
        
    def forward(self,x):
        x = F.relu(self.rn(x))
        x = self.up1(x, self.sfs[3].features)
        x = self.up2(x, self.sfs[2].features)
        x = self.up3(x, self.sfs[1].features)
        x = self.up4(x, self.sfs[0].features)
        x = self.up5(x)
        return x[:,0]
    
    def close(self):
        for sf in self.sfs: sf.remove()

# %%
class UnetModel():
    def __init__(self,model,name='unet'):
        self.model,self.name = model,name

    def get_layer_groups(self, precompute):
        lgs = list(split_by_idxs(children(self.model.rn), [lr_cut]))
        return lgs + [children(self.model)[1:]]

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 32, 32]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 16, 16]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-25',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 64, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-26',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-27',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-28',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-29',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-30',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-40',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-41',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-48',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-49',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-50',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-51',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-52',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-53',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-54',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-55',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-59',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-60',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-61',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-62',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-63',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-64',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-65',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-66',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-67',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-68',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-69',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-70',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-71',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-78',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-79',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-80',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-81',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-82',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-83',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-84',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-85',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-92',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-93',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-94',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-95',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-96',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-97',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-98',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-99',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('Conv2d-100',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-101',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-102',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-103',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-104',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-105',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-106',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-107',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-108',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-109',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-110',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-111',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-112',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-113',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-114',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-115',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-122',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-123',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 128, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 262272)])),
#              ('Conv2d-124',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 128, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 32896)])),
#              ('BatchNorm2d-125',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-126',
#               OrderedDict([('input_shape', [-1, 512, 1, 1]),
#                            ('output_shape', [-1, 256, 2, 2]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-127',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 128, 4, 4]),
#                            ('output_shape', [-1, 128, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 16512)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-130',
#               OrderedDict([('input_shape', [-1, 256, 2, 2]),
#                            ('output_shape', [-1, 256, 4, 4]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-131',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-132',
#               OrderedDict([('input_shape', [-1, 64, 8, 8]),
#                            ('output_shape', [-1, 128, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 8320)])),
#              ('BatchNorm2d-133',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-134',
#               OrderedDict([('input_shape', [-1, 256, 4, 4]),
#                            ('output_shape', [-1, 256, 8, 8]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-135',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 128, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 131200)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 64, 16, 16]),
#                            ('output_shape', [-1, 128, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 8320)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 256, 16, 16]),
#                            ('output_shape', [-1, 256, 16, 16]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('UnetBlock-138',
#               OrderedDict([('input_shape', [-1, 256, 8, 8]),
#                            ('output_shape', [-1, 256, 16, 16]),
#                            ('nb_params', 0)])),
#              ('ConvTranspose2d-139',
#               OrderedDict([('input_shape', [-1, 256, 16, 16]),
#                            ('output_shape', [-1, 1, 32, 32]),
#                            ('trainable', True),
#                            ('nb_params', 1025)]))])

# %%
[o.features.size() for o in m.sfs]
# Out:
# [torch.Size([3, 64, 16, 16]),
#  torch.Size([3, 64, 8, 8]),
#  torch.Size([3, 128, 4, 4]),
#  torch.Size([3, 256, 2, 2])]

# %%
learn.freeze_to(1)

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))

# %%
lr=2e-2
wd=1e-7

lrs = np.array([lr/9,lr/3,lr])

# %%
learn.fit(lr,1,wds=wd,cycle_len=10,use_clr=(5,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=10), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.324962   0.35021    0.873533   0.69908
#     1      0.2784     0.244249   0.894323   0.757877
#     2      0.245401   0.258634   0.906572   0.811245
#     3      0.231068   0.244012   0.908881   0.810126
#     4      0.20726    0.226295   0.911876   0.809426
#     5      0.190085   0.212798   0.916592   0.820263
#     6      0.179161   0.246382   0.916816   0.838386
#     7      0.166471   0.222223   0.921831   0.836819
#     8      0.148915   0.217064   0.919303   0.829623
#     9      0.142128   0.210294   0.927793   0.852344
# [array([0.21029]), 0.92779296875, 0.852344447275771]

# %%
learn.save('32urn-tmp')

# %%
learn.load('32urn-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
learn.fit(lrs/2, 1, wds=wd, cycle_len=20,use_clr=(20,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=20), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.183886   0.233078   0.906421   0.78914
#     1      0.233754   0.228571   0.90428    0.789016
#     2      0.220028   0.212972   0.912496   0.809266
#     3      0.208927   0.226777   0.903551   0.785285
#     4      0.20269    0.213244   0.90897    0.796054
#     5      0.184726   0.197221   0.923036   0.834551
#     6      0.157264   0.215982   0.916097   0.818172
#     7      0.142905   0.230303   0.91834    0.842702
#     8      0.13617    0.205643   0.926084   0.848377
#     9      0.120178   0.224034   0.922882   0.84252
#     10     0.110852   0.224434   0.920796   0.842043
#     11     0.10254    0.201666   0.928727   0.854405
#     12     0.091366   0.206962   0.929153   0.853166
#     13     0.078525   0.224045   0.933815   0.86077
#     14     0.072085   0.224472   0.930668   0.857304
#     15     0.06976    0.224569   0.931067   0.851837
#     16     0.066028   0.222942   0.933036   0.857978
#     17     0.061951   0.22262    0.93549    0.864986
#     18     0.058078   0.227388   0.936074   0.865938
#     19     0.054633   0.232593   0.934844   0.862067
# [array([0.23259]), 0.93484375, 0.86206661404237]

# %%
learn.sched.plot_lr()

# %%
learn.save('32urn-0')

# %%
learn.load('32urn-0')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[0]>0.5);

# %%
show_img(y[0]);

# %%
show_img(x[0][0]);

# %%
m.close()

# %% [markdown]
# ## 64x64

# %%
sz=64
bs=64

# %%
tfms = tfms_from_model(resnet34, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.freeze_to(1)

# %%
learn.load('32urn-0')

# %%
learn.fit(lr/2,1,wds=wd, cycle_len=10,use_clr=(10,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=10), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.214672   0.202273   0.92298    0.841774
#     1      0.184592   0.19298    0.933186   0.864824
#     2      0.163282   0.160778   0.938561   0.87118
#     3      0.155378   0.177791   0.934208   0.856586
#     4      0.137522   0.164605   0.941956   0.877882
#     5      0.125542   0.164246   0.938013   0.875904
#     6      0.110169   0.170783   0.942333   0.883487
#     7      0.098533   0.156592   0.946172   0.889436
#     8      0.088403   0.166128   0.946232   0.887965
#     9      0.083359   0.163788   0.945189   0.887378
# [array([0.16379]), 0.945189208984375, 0.887378283507889]

# %%
learn.sched.plot_lr()

# %%
learn.save('64urn-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
learn.load('64urn-tmp')

# %%
learn.fit(lrs/2,1,wds=wd, cycle_len=10,use_clr=(20,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=10), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0.112993   0.181226   0.933926   0.860897
#     1      0.13811    0.173146   0.93898    0.872428
#     2      0.144502   0.179065   0.93023    0.845505
#     3      0.131877   0.161754   0.94077    0.877714
#     4      0.108722   0.156998   0.942069   0.880905
#     5      0.089146   0.178915   0.943474   0.881318
#     6      0.076669   0.1721     0.947239   0.891213
#     7      0.065926   0.164302   0.948796   0.896314
#     8      0.057186   0.166394   0.949237   0.894631
#     9      0.052058   0.164856   0.950204   0.897039
# [array([0.16486]), 0.9502041625976563, 0.8970389099982785]

# %%
learn.sched.plot_lr()

# %%
learn.save('64urn')

# %%
learn.load('64urn')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[0]>0.5);

# %%
show_img(y[0]);

# %%
show_img(x[0][0]);

# %%
m.close()

# %% [markdown]
# ## 128x128

# %%
sz=128
bs=64

# %%
tfms = tfms_from_model(resnet34, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('64urn')

# %%
learn.fit(lr,1, wds=wd, cycle_len=20,use_clr=(20,8))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=20), HTML(value='')))
# epoch      trn_loss   val_loss   <lambda>   dice
#     0      0
# %%
batches = [next(iter(md.aug_dl)) for i in range(9)]

# %%
fig, axes = plt.subplots(3, 6, figsize=(18, 9))
for i,(x,y) in enumerate(batches):
    show_aug_img(x,1, ax=axes.flat[i*2])
    show_aug_img(y,1, ax=axes.flat[i*2+1], nchannels=1, normed=False)

# %% [markdown]
# # Test on original validation

# %%
x_names_orig = np.array(glob(f'{PATH}/train/*'))
y_names_orig = np.array(glob(f'{PATH}/train_masks/*'))

# %%
val_idxs_orig = list(range(800))
((val_x_orig,trn_x_orig),(val_y_orig,trn_y_orig)) = split_by_idx(val_idxs_orig, x_names_orig, y_names_orig)

# %%
sz=128
bs=64

# %%
tfms = tfms_from_model(resnet34, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('128urn')

# %%
probs = learn.predict()

# %%
probs.shape
# Out:
# (800, 128, 128)

# %%
_, y = learn.TTA(n_aug=1)

# %%
y.shape
# Out:
# (800, 128, 128)

# %%
idx=0

# %%
show_img(probs[idx]>0.5);

# %%
show_img(probs[idx]);

# %%
show_img(y[idx]);

# %%
show_img(x[idx][0]);

# %% [markdown]
# # Optimise threshold

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thres = np.linspace(-1, 1, 10)
thres_ioc = [iou_metric_batch(y, np.int32(probs > t)) for t in tqdm_notebook(thres)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))

# %%
plt.plot(thres, thres_ioc);

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.11111111111111116, 0.796375)

# %%
thres = np.linspace(0, 1, 10)
thres_ioc = [iou_metric_batch(y, np.int32(probs > t)) for t in tqdm_notebook(thres)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))

# %%
plt.plot(thres, thres_ioc);

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.2222222222222222, 0.7966250000000001)

# %%
show_img(probs[0]>best_thres);

# %% [markdown]
# # Run on test

# %%
(PATH/'test-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'test-128'/fn.name)

files = list((PATH/'test').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %%
testData = np.array(glob(f'{PATH}/test-128/*'))

# %%
class TestFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.fnames[i]))
    def get_c(self): return 0

# %%
tfms_from_model(resnet34, sz, crop_type=CropType.NO, tfm_y=TfmType.CLASS, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(TestFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, test=testData, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)
denorm = md.trn_ds.denorm

# %%
m_base = get_base()
m = to_gpu(Unet34(m_base))
models = UnetModel(m)

# %%
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=nn.BCEWithLogitsLoss()
learn.metrics=[accuracy_thresh(0.5),dice]

# %%
learn.load('128urn')

# %%
x,y = next(iter(md.test_dl))
py = to_np(learn.model(V(x)))

# %%
show_img(py[6]>best_thres);

# %%
show_img(py[6]);

# %%
show_img(y[6]);

# %%
probs = learn.predict(is_test=True)

# %%
show_img(probs[12]>best_thres);

# %%
show_img(probs[12]);

# %%
show_img(y[12]);

# %%
show_img(x[12][0]);

# %%
with open(f'{PATH}/probs.pkl', 'wb') as fout: #Save results
    pickle.dump(probs, fout)

# %%
probs.shape
# Out:
# (18000, 128, 128)

# %%
def resize_img(fn):
    return np.array(Image.fromarray(fn).resize((101,101)))

resizePreds = np.array([resize_img(x) for x in probs])

# %%
resizePreds.shape
# Out:
# (18000, 101, 101)

# %%
show_img(resizePreds[12]);

# %%
testData
# Out:
# array(['/home/giles/Downloads/fastai_data/salt/test-128/ac26efe98e.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/0a5eac8775.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/bdb1c1fcbf.png', ...,
#        '/home/giles/Downloads/fastai_data/salt/test-128/3bceaa0303.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/96867a3897.png',
#        '/home/giles/Downloads/fastai_data/salt/test-128/52f6267e3f.png'], dtype='<U62')

# %%
f'{PATH}/test'
# Out:
# '/home/giles/Downloads/fastai_data/salt/test'

# %%
test_ids = next(os.walk(f'{PATH}/test'))[2]

# %%
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

# %%
pred_dict = {id_[:-4]:RLenc(np.round(resizePreds[i] > best_thres)) for i,id_ in tqdm_notebook(enumerate(test_ids))}
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')

#